# %%
import sys
import operator
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>3</td><td>application_1589862977500_0004</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-68-12.ec2.internal:20888/proxy/application_1589862977500_0004/">Link</a></td><td><a target="_blank" href="http://ip-172-31-64-133.ec2.internal:8042/node/containerlogs/container_1589862977500_0004_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StringType
from pyspark.sql.window import Window
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
airport_data = "s3://air-traffic-dataset/ontimeperformance_airports.csv"
aircraft_data = "s3://air-traffic-dataset/ontimeperformance_aircrafts.csv"
airlines_data = "s3://air-traffic-dataset/ontimeperformance_airlines.csv"

flights_tiny = "s3://air-traffic-dataset/ontimeperformance_flights_tiny.csv"
flights_small = "s3://air-traffic-dataset/ontimeperformance_flights_small.csv"
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
airlines_df = spark.read.csv(airlines_data, header=True).cache()
aircraft_df = spark.read.csv(aircraft_data, header=True).cache()
airport_df = spark.read.csv(airport_data, header=True).cache()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# # Task 1

# %%
flights_tiny_df = spark.read.csv(flights_tiny, header=True)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
cessna_models = aircraft_df \
    .filter(aircraft_df["manufacturer"] == "CESSNA") \
    .withColumn("modelName", F.regexp_extract(F.col("model"), 
                                 '\d{3}', 0))
cessna_models \
    .select("manufacturer", "model", "modelName", "tailnum") \
    .cache()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# DataFrame[manufacturer: string, model: string, modelName: string, tailnum: string]

# %%
cessna_models.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+-----------+------------+----------+----------+------+--------------------+-------------+----+---------+
# |tailnum|       type|manufacturer|issue_date|     model|status|       aircraft_type|  engine_type|year|modelName|
# +-------+-----------+------------+----------+----------+------+--------------------+-------------+----+---------+
# | N201AA|   Co-Owner|      CESSNA|04/14/1992|       150| Valid|Fixed Wing Single...|Reciprocating|1959|      150|
# | N202AA|Corporation|      CESSNA|02/12/1996|      421C| Valid|Fixed Wing Multi-...|Reciprocating|1980|      421|
# |   N293|Corporation|      CESSNA|04/18/2007|     T337G| Valid|Fixed Wing Multi-...|Reciprocating|1975|      337|
# | N3744D| Individual|      CESSNA|07/29/1987|      182A| Valid|Fixed Wing Single...|Reciprocating|1957|      182|
# | N378AA| Individual|      CESSNA|06/06/2008|      172E| Valid|Fixed Wing Single...|Reciprocating|1963|      172|
# | N421AA|Corporation|      CESSNA|10/24/2007|      421C| Valid|Fixed Wing Multi-...|Reciprocating|1962|      421|
# | N444AA| Individual|      CESSNA|03/28/1978|      182P| Valid|Fixed Wing Single...|Reciprocating|1973|      182|
# | N474AA|Corporation|      CESSNA|08/13/1993|      172M| Valid|Fixed Wing Single...|      4 Cycle|1974|      172|
# | N510AA|Corporation|      CESSNA|11/26/1997|     T210N| Valid|Fixed Wing Single...|Reciprocating|1982|      210|
# | N519AA|Corporation|      CESSNA|09/12/2005|       550| Valid|Fixed Wing Multi-...|    Turbo-Fan|1979|      550|
# | N575AA|   Co-Owner|      CESSNA|06/19/1991|210-5(205)| Valid|Fixed Wing Single...|Reciprocating|1963|      210|
# | N621AA| Individual|      CESSNA|06/13/2003|      172M| Valid|Fixed Wing Single...|      4 Cycle|1975|      172|
# +-------+-----------+------------+----------+----------+------+--------------------+-------------+----+---------+

# %%
flights_count = flights_tiny_df.groupby("tail_number") \
    .count() \
    .cache()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
cessna_results = cessna_models.join(flights_count, cessna_models.tailnum == flights_count.tail_number, how="left") \
    .groupby("modelName") \
    .sum("count") \
    .sort("sum(count)", ascending=False).cache()
cessna_results.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------+----------+
# |modelName|sum(count)|
# +---------+----------+
# |      421|       535|
# |      210|       474|
# |      172|       399|
# |      182|       350|
# |      150|       254|
# |      550|       248|
# |      337|         8|
# +---------+----------+

# %%
results = cessna_results.collect()
results
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# [Row(modelName='421', sum(count)=535), Row(modelName='210', sum(count)=474), Row(modelName='172', sum(count)=399), Row(modelName='182', sum(count)=350), Row(modelName='150', sum(count)=254), Row(modelName='550', sum(count)=248), Row(modelName='337', sum(count)=8)]

# %%
def printCessnaModels(cessna_results):
    results = cessna_results.collect()
    results.sort(key=operator.itemgetter(1), reverse=True)
    for i in range(3):
        print("Cessna {} \t {}".format(
            results[i][0], 
            results[i][1]),
            file=sys.stdout
        )
        
printCessnaModels(cessna_results)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Cessna 421 	 535
# Cessna 210 	 474
# Cessna 172 	 399

# %% [markdown]
# # Task 2

# %%
flights_tiny_df = spark.read.csv(flights_tiny, header=True)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
flight_cols = [
    "carrier_code",
    "tail_number",
    "delayed_time"
]
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
flights_tiny_df.printSchema()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- flight_id: string (nullable = true)
#  |-- carrier_code: string (nullable = true)
#  |-- flight_number: string (nullable = true)
#  |-- flight_date: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- destination: string (nullable = true)
#  |-- tail_number: string (nullable = true)
#  |-- scheduled_depature_time: string (nullable = true)
#  |-- scheduled_arrival_time: string (nullable = true)
#  |-- actual_departure_time: string (nullable = true)
#  |-- actual_arrival_time: string (nullable = true)
#  |-- distance: string (nullable = true)

# %%
flights_tiny_df \
    .filter(F.col("actual_departure_time") == "24:00:00") \
    .select("flight_id", "carrier_code", "scheduled_depature_time", "actual_departure_time") \
    .show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------+------------+-----------------------+---------------------+
# |flight_id|carrier_code|scheduled_depature_time|actual_departure_time|
# +---------+------------+-----------------------+---------------------+
# |  5301680|          US|               23:55:00|             24:00:00|
# |  5437149|          UA|               23:55:00|             24:00:00|
# |  6170238|          US|               23:45:00|             24:00:00|
# |  7274936|          DL|               22:45:00|             24:00:00|
# |  8144810|          DL|               23:50:00|             24:00:00|
# +---------+------------+-----------------------+---------------------+
# only showing top 5 rows

# %%
YEAR = 1996

flights_tiny_df = flights_tiny_df \
    .filter(flights_tiny_df["flight_date"].between(
        "{}-01-01".format(YEAR), 
        "{}-12-31".format(YEAR))
    )
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
flights_tiny_df = flights_tiny_df \
    .withColumn(
        "scheduled_departure_timestamp", 
        F.to_timestamp(
            F.when(
                F.col("scheduled_depature_time") == "24:00:00",
                "00:00:00"
            ).otherwise(F.col("scheduled_depature_time")),
            "HH:mm:ss"
        )
    ) \
    .withColumn(
        "actual_departure_timestamp", 
        F.to_timestamp(
            F.when(
                F.col("actual_departure_time") == "24:00:00",
                "00:00:00"
            ).otherwise(F.col("actual_departure_time")),
            "HH:mm:ss"
        )
    )
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
flights_tiny_df = flights_tiny_df \
    .withColumn("delayed_time",
        F.when(
            F.col("actual_departure_timestamp").cast("long") -
            F.col("scheduled_departure_timestamp").cast("long") > (60*60*12),
            (
                F.col("scheduled_departure_timestamp").cast("long") + (60*60*24) -
                F.col("actual_departure_timestamp").cast("long")
            )/60
        ).when(
            F.col("scheduled_departure_timestamp").cast("long") -
            F.col("actual_departure_timestamp").cast("long") > (60*60*12),
            (
                F.col("actual_departure_timestamp").cast("long") + (60*60*24) -
                F.col("scheduled_departure_timestamp").cast("long")
            )/60
        ).otherwise(
            (F.col("actual_departure_timestamp").cast("long") -
             F.col("scheduled_departure_timestamp").cast("long")
            )/60
        )
    )
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
flights_tiny_df \
    .filter(F.col("actual_departure_time") == "24:00:00") \
    .select("flight_id", "carrier_code", 
#             "scheduled_depature_time", "scheduled_departure_timestamp",
            "actual_departure_time", "actual_departure_timestamp") \
    .show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---------+------------+---------------------+--------------------------+
# |flight_id|carrier_code|actual_departure_time|actual_departure_timestamp|
# +---------+------------+---------------------+--------------------------+
# | 15759452|          DL|             24:00:00|       1970-01-01 00:00:00|
# | 18640553|          UA|             24:00:00|       1970-01-01 00:00:00|
# +---------+------------+---------------------+--------------------------+

# %%
flights_tiny_df.select(flight_cols) \
    .show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------+-----------+------------+
# |carrier_code|tail_number|delayed_time|
# +------------+-----------+------------+
# |          DL|     N536DA|        20.0|
# |          DL|     N629DL|        90.0|
# |          DL|     N604DL|         8.0|
# |          DL|     N633DL|        11.0|
# |          HP|     N906AW|        39.0|
# |          HP|     N914AW|         0.0|
# |          HP|     N905AW|         4.0|
# |          HP|     N181AW|        -1.0|
# |          HP|     N183AW|        -4.0|
# |          HP|     N632AW|        12.0|
# |          HP|     N638AW|        -4.0|
# |          HP|     N179AW|         0.0|
# |          HP|     N639AW|        32.0|
# |          HP|     N185AW|         0.0|
# |          HP|     N627AW|         0.0|
# |          UA|     N1814U|        48.0|
# |          UA|     N345UA|         2.0|
# |          UA|     N7254U|        25.0|
# |          UA|     N574UA|        17.0|
# |          UA|     N556UA|        20.0|
# +------------+-----------+------------+
# only showing top 20 rows

# %%
flights_tiny_df.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
flights_tiny_df = flights_tiny_df \
    .filter(F.col("actual_departure_timestamp").isNotNull())
flights_tiny_df.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 54759

# %%
avg_flights = flights_tiny_df.select(flight_cols) \
    .filter(F.col("delayed_time") > 0) \
    .groupBy("carrier_code") \
    .agg(
        F.count('delayed_time').alias("numOfDelays"),
        F.mean('delayed_time').alias("avgDelays"),
        F.min('delayed_time').alias("minDelay"),
        F.max('delayed_time').alias("maxDelay")
    ) \
    .withColumn("avgDelays", F.round(F.col("avgDelays"), 2)) \
    .join(airlines_df, 
          flights_tiny_df.carrier_code == airlines_df.carrier_code
    ) \
    .select("name", "numOfDelays", "avgDelays", "minDelay", "maxDelay")
avg_flights.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+-----------+---------+--------+--------+
# |                name|numOfDelays|avgDelays|minDelay|maxDelay|
# +--------------------+-----------+---------+--------+--------+
# |     United Airlines|       8975|    21.39|     1.0|   705.0|
# |American Airlines...|       6707|   117.17|     1.0|   719.0|
# |Northwest Airline...|       2123|    27.23|     1.0|   373.0|
# |    Sparrow Aviation|       1086|    28.48|     1.0|   578.0|
# |            Tway Air|        590|    35.29|     1.0|   454.0|
# |Delta Air Lines Inc.|       6288|     20.4|     1.0|   380.0|
# |          US Airways|        823|    18.54|     1.0|   420.0|
# |Alaska Airlines Inc.|        219|    29.56|     1.0|   185.0|
# |Continental Air L...|       3182|    20.27|     1.0|   315.0|
# |Southwest Airline...|       1537|     23.4|     1.0|   247.0|
# +--------------------+-----------+---------+--------+--------+

# %%
avg_flights.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 10

# %%
def parseAvgFlights(avg_flights_df):
    results = avg_flights_df.collect()
    results.sort(key=operator.itemgetter(0))
    for i in range(len(results)):
        print("{} \t {} \t {} \t {} \t {}".format(
            results[i][0], 
            results[i][1],
            results[i][2],
            results[i][3],
            results[i][4]
        ), file=sys.stdout)
        
parseAvgFlights(avg_flights)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Alaska Airlines Inc. 	 219 	 29.56 	 1.0 	 185.0
# American Airlines Inc. 	 6707 	 117.17 	 1.0 	 719.0
# Continental Air Lines Inc. 	 3182 	 20.27 	 1.0 	 315.0
# Delta Air Lines Inc. 	 6288 	 20.4 	 1.0 	 380.0
# Northwest Airlines Inc. 	 2123 	 27.23 	 1.0 	 373.0
# Southwest Airlines Co. 	 1537 	 23.4 	 1.0 	 247.0
# Sparrow Aviation 	 1086 	 28.48 	 1.0 	 578.0
# Tway Air 	 590 	 35.29 	 1.0 	 454.0
# US Airways 	 823 	 18.54 	 1.0 	 420.0
# United Airlines 	 8975 	 21.39 	 1.0 	 705.0

# %% [markdown]
# # Task 3

# %%
airlines_df.select(F.col("country")) \
    .distinct() \
    .count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 82

# %%
airlines_df \
    .filter(F.col("country") == "United States") \
    .filter(F.col("name").like("%Tran%")) \
    .sort("name") \
    .show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------+--------------------+-------------+
# |carrier_code|                name|      country|
# +------------+--------------------+-------------+
# |          8C|Air Transport Int...|United States|
# |          FL|             AirTran|United States|
# |         CTL|Coastal Air Trans...|United States|
# |         CTQ|Custom Air Transport|United States|
# |         TIA|      Trans Air Inc.|United States|
# |         TIE|Trans Internation...|United States|
# |         PDA|Trans Southern Ai...|United States|
# |          AX|Trans States Airl...|United States|
# |         TWA|Trans Western Air...|United States|
# |         TWE| Trans World Express|United States|
# |         TCO|Trans-Colorado Ai...|United States|
# |          T9|Transmeridian Air...|United States|
# +------------+--------------------+-------------+

# %%
airlines_df.select(F.col("country")) \
    .distinct() \
    .show(10)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------+
# |          country|
# +-----------------+
# |           Russia|
# |           Sweden|
# |Republic of Korea|
# |      Philippines|
# |        Singapore|
# |         Malaysia|
# |             Iraq|
# |          Germany|
# |         Maldives|
# |      Ivory Coast|
# +-----------------+
# only showing top 10 rows

# %%
COUNTRY="United States"
FILE=flights_tiny
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
flights_tiny_df = spark.read.csv(FILE, header=True)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
aircraft_col = [
    "manufacturer", 
    "model",
    "modelName",
    "tailnum",
]

'''
QUESTION 1: If we drop the null values for aircraft, then
            what's gonna happen if there is a tailNum but 
            there's no model + manufacturer for it?
            
            Well... there's no info to output for
            aircraft type as well so...
'''

aircraft_modelName = aircraft_df \
    .filter(F.col("manufacturer").isNotNull()) \
    .filter(F.col("model").isNotNull()) \
    .withColumn("modelName", 
                F.regexp_extract(
                    F.col("model"), '\d{3}', 0)
               ) \
    .select(aircraft_col)
aircraft_modelName.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----------------+---------+---------+-------+
# |    manufacturer|    model|modelName|tailnum|
# +----------------+---------+---------+-------+
# |         EMBRAER|EMB-145XR|      145| N10156|
# |AIRBUS INDUSTRIE| A320-214|      320| N102UW|
# |          BOEING|  737-3TO|      737| N10323|
# |AIRBUS INDUSTRIE| A320-214|      320| N103US|
# |          BOEING|  747-422|      747| N104UA|
# |AIRBUS INDUSTRIE| A320-214|      320| N104UW|
# |         EMBRAER|EMB-145LR|      145| N10575|
# |          BOEING|  747-451|      747| N105UA|
# |AIRBUS INDUSTRIE| A320-214|      320| N105UW|
# |AIRBUS INDUSTRIE| A320-214|      320| N106US|
# |          BOEING|  747-422|      747| N107UA|
# |AIRBUS INDUSTRIE| A320-214|      320| N107US|
# |AIRBUS INDUSTRIE| A320-214|      320| N108UW|
# |AIRBUS INDUSTRIE| A320-214|      320| N109UW|
# |AIRBUS INDUSTRIE| A320-214|      320| N110UW|
# |         EMBRAER|EMB-145XR|      145| N11106|
# |         EMBRAER|EMB-145XR|      145| N11107|
# |         EMBRAER|EMB-145XR|      145| N11109|
# |         EMBRAER|EMB-145XR|      145| N11113|
# |         EMBRAER|EMB-145XR|      145| N11119|
# +----------------+---------+---------+-------+
# only showing top 20 rows

# %%
airlines_df.filter(airlines_df["country"] == COUNTRY) \
    .join(flights_tiny_df, airlines_df.carrier_code == flights_tiny_df.carrier_code) \
    .show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------+---------------+-------------+---------+------------+-------------+-----------+------+-----------+-----------+-----------------------+----------------------+---------------------+-------------------+--------+
# |carrier_code|           name|      country|flight_id|carrier_code|flight_number|flight_date|origin|destination|tail_number|scheduled_depature_time|scheduled_arrival_time|actual_departure_time|actual_arrival_time|distance|
# +------------+---------------+-------------+---------+------------+-------------+-----------+------+-----------+-----------+-----------------------+----------------------+---------------------+-------------------+--------+
# |          UA|United Airlines|United States|  5017626|          UA|          370| 1994-05-23|   ORD|        PIT|       null|               20:15:00|              22:32:00|             20:17:00|           22:42:00|     412|
# |          UA|United Airlines|United States|  5017876|          UA|          376| 1994-05-12|   ORD|        PHL|       null|               18:00:00|              20:53:00|             18:00:00|           20:37:00|     678|
# |          UA|United Airlines|United States|  5017887|          UA|          376| 1994-05-26|   ORD|        PHL|       null|               18:00:00|              20:53:00|             18:03:00|           21:23:00|     678|
# |          UA|United Airlines|United States|  5017948|          UA|          379| 1994-05-03|   ORD|        OAK|       null|               15:40:00|              18:04:00|             15:45:00|           18:04:00|    1835|
# |          UA|United Airlines|United States|  5017951|          UA|          379| 1994-05-06|   ORD|        OAK|       null|               15:40:00|              18:04:00|             15:50:00|           18:26:00|    1835|
# |          UA|United Airlines|United States|  5017963|          UA|          379| 1994-05-18|   ORD|        OAK|       null|               15:40:00|              18:04:00|             15:41:00|           17:57:00|    1835|
# |          UA|United Airlines|United States|  5018028|          UA|          380| 1994-05-22|   ORD|        BUF|       null|               16:55:00|              19:25:00|             16:55:00|           19:32:00|     473|
# |          UA|United Airlines|United States|  5018175|          UA|          383| 1994-05-02|   ORD|        OMA|       null|               21:50:00|              23:17:00|             21:53:00|           23:16:00|     416|
# |          UA|United Airlines|United States|  5018247|          UA|          385| 1994-05-22|   DEN|        SLC|       null|               14:45:00|              16:04:00|             14:44:00|           16:01:00|     391|
# |          UA|United Airlines|United States|  5018422|          UA|          389| 1994-05-26|   DEN|        OAK|       null|               08:45:00|              10:19:00|             08:43:00|           10:09:00|     957|
# |          UA|United Airlines|United States|  5018444|          UA|          390| 1994-05-19|   ORD|        TYS|       null|               07:44:00|              10:07:00|             07:46:00|           10:05:00|     475|
# |          UA|United Airlines|United States|  5018516|          UA|          392| 1994-05-10|   ORD|        MDT|       null|               17:25:00|              20:07:00|             17:25:00|           19:48:00|     594|
# |          UA|United Airlines|United States|  5018542|          UA|          393| 1994-05-05|   ATL|        ORD|       null|               08:00:00|              08:55:00|             08:02:00|           09:10:00|     606|
# |          UA|United Airlines|United States|  5018861|          UA|          401| 1994-05-14|   ORD|        SJC|       null|               12:40:00|              15:14:00|             12:47:00|           15:18:00|    1829|
# |          UA|United Airlines|United States|  5018878|          UA|          401| 1994-05-31|   ORD|        SJC|       null|               12:40:00|              15:14:00|             12:37:00|           15:19:00|    1829|
# |          UA|United Airlines|United States|  5018888|          UA|          403| 1994-05-12|   DEN|        BIL|       null|               19:17:00|              20:35:00|             19:25:00|           20:41:00|     455|
# |          UA|United Airlines|United States|  5018982|          UA|          404| 1994-05-22|   ORD|        RDU|       null|               13:30:00|              16:22:00|             13:34:00|           16:23:00|     647|
# |          UA|United Airlines|United States|  5018986|          UA|          404| 1994-05-26|   ORD|        RDU|       null|               13:30:00|              16:22:00|             13:31:00|           16:55:00|     647|
# |          UA|United Airlines|United States|  5019041|          UA|          405| 1994-05-26|   DEN|        SFO|       null|               20:50:00|              22:23:00|             20:50:00|           22:26:00|     967|
# |          UA|United Airlines|United States|  5019056|          UA|          406| 1994-05-11|   ORD|        SAV|       null|               10:55:00|              13:45:00|             10:56:00|           13:39:00|     773|
# +------------+---------------+-------------+---------+------------+-------------+-----------+------+-----------+-----------+-----------------------+----------------------+---------------------+-------------------+--------+
# only showing top 20 rows

# %%
airlines_all_counts = airlines_df.filter(airlines_df["country"] == COUNTRY) \
    .join(flights_tiny_df, airlines_df.carrier_code == flights_tiny_df.carrier_code) \
    .drop(flights_tiny_df.carrier_code) \
    .filter(F.col("actual_departure_time").isNotNull()) \
    .groupBy("name", "carrier_code", "tail_number") \
    .count() \
    .join(aircraft_modelName, 
        flights_tiny_df.tail_number == aircraft_modelName.tailnum,
        how="left"
    ) \
    .filter(F.col("manufacturer").isNotNull()) \
    .filter(F.col("model").isNotNull()) \
    .groupBy("name", "manufacturer", "model") \
    .sum("count") \
    .withColumnRenamed("sum(count)", "numFlights") \
    .cache()
airlines_all_counts.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+-----------------+---------+----------+
# |                name|     manufacturer|    model|numFlights|
# +--------------------+-----------------+---------+----------+
# |Delta Air Lines Inc.|           BOEING|  767-332|      6489|
# |Delta Air Lines Inc.|MCDONNELL DOUGLAS| MD-90-30|      2270|
# |Alaska Airlines Inc.|           BOEING|  737-8FH|        30|
# |Southwest Airline...|           CESSNA|    T337G|         8|
# |Northwest Airline...|           AIRBUS| A319-114|      2240|
# |Continental Air L...|           BOEING|  737-824|      9467|
# |     United Airlines| AIRBUS INDUSTRIE| A320-232|     15134|
# |          US Airways|           AIRBUS| A320-232|       724|
# |     United Airlines|           AIRBUS| A319-131|       702|
# |   PSA Airlines Inc.|            PIPER|PA-28-180|        34|
# |American Airlines...|           BOEING|  757-223|      3708|
# |American Airlines...|           CESSNA|     421C|       535|
# |Delta Air Lines Inc.|           BOEING|777-232LR|         2|
# |Alaska Airlines Inc.|           BOEING|  737-490|       814|
# |Frontier Airlines...|           AIRBUS| A319-112|       511|
# |          US Airways| AIRBUS INDUSTRIE| A321-211|       722|
# |American Airlines...|      PAIR MIKE E|FALCON XP|        70|
# |Delta Air Lines Inc.|           BOEING|  757-232|     20554|
# |American Airlines...|   AERO COMMANDER|     690A|        57|
# |American Airlines...|            BEECH|       60|       254|
# +--------------------+-----------------+---------+----------+
# only showing top 20 rows

# %%
airlines_all_counts.groupBy("name") \
    .count() \
    .show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+-----+
# |                name|count|
# +--------------------+-----+
# |    Independence Air|    1|
# |        JetSuite Air|    6|
# |Skywest Airlines ...|    6|
# |American Eagle Ai...|    6|
# |     United Airlines|   11|
# |              Comair|    5|
# |   PSA Airlines Inc.|    5|
# |Frontier Airlines...|    6|
# |Southwest Airline...|   22|
# |Continental Air L...|   13|
# |Northwest Airline...|   16|
# |     JetBlue Airways|    3|
# |          US Airways|   24|
# |Hawaiian Airlines...|    4|
# |             AirTran|    3|
# |Atlantic Southeas...|    5|
# |Alaska Airlines Inc.|    9|
# |Delta Air Lines Inc.|   17|
# |  Mesa Airlines Inc.|    6|
# |American Airlines...|   43|
# +--------------------+-----+

# %% [markdown]
# We don't groupBy with "modelName" for now because some of the names will disappear
#
# `.groupBy("name", "manufacturer", "model", "modelName") \`

# %%
window = Window.partitionBy(
    airlines_all_counts["name"]).orderBy(
    airlines_all_counts["numFlights"].desc()
)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
'''
QUESTION 2: If we drop the null values for manufacturer and
            and model now, then we won't incorrectly count
            the number of flights since "null" was grouped
            together in the previous function.
'''

airlines_model_ranking = airlines_all_counts \
    .select("*", F.rank().over(window).alias("rank")) \
    .filter(F.col("rank") <=5) \
    .sort(["name", "rank"], ascending=True)
airlines_model_ranking.show(100)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+--------------------+---------------+----------+----+
# |                name|        manufacturer|          model|numFlights|rank|
# +--------------------+--------------------+---------------+----------+----+
# |             AirTran|              BOEING|        717-200|     11225|   1|
# |             AirTran|              BOEING|        737-76N|      1858|   2|
# |             AirTran|              BOEING|        737-7BD|      1674|   3|
# |Alaska Airlines Inc.|              BOEING|        737-4Q8|      1380|   1|
# |Alaska Airlines Inc.|              BOEING|        737-790|       859|   2|
# |Alaska Airlines Inc.|              BOEING|        737-490|       814|   3|
# |Alaska Airlines Inc.|   MCDONNELL DOUGLAS| DC-9-83(MD-83)|       767|   4|
# |Alaska Airlines Inc.|              BOEING|        737-990|       441|   5|
# |American Airlines...|   MCDONNELL DOUGLAS| DC-9-82(MD-82)|     37353|   1|
# |American Airlines...|   MCDONNELL DOUGLAS| DC-9-83(MD-83)|      7019|   2|
# |American Airlines...|              BOEING|        757-223|      3708|   3|
# |American Airlines...|              BOEING|        767-223|      2229|   4|
# |American Airlines...|              BOEING|        767-323|      1559|   5|
# |American Eagle Ai...|             EMBRAER|      EMB-145LR|     13392|   1|
# |American Eagle Ai...|             EMBRAER|      EMB-135KL|      5400|   2|
# |American Eagle Ai...|      BOMBARDIER INC|    CL-600-2C10|      2898|   3|
# |American Eagle Ai...|         SAAB-SCANIA|      SAAB 340B|      1799|   4|
# |American Eagle Ai...|             EMBRAER|      EMB-135LR|      1184|   5|
# |Atlantic Southeas...|      BOMBARDIER INC|    CL-600-2B19|     14337|   1|
# |Atlantic Southeas...|      BOMBARDIER INC|    CL-600-2C10|      3472|   2|
# |Atlantic Southeas...|            CANADAIR|    CL-600-2B19|      1693|   3|
# |Atlantic Southeas...| AEROSPATIALE/ALENIA|     ATR-72-212|      1158|   4|
# |Atlantic Southeas...|        AEROSPATIALE|     ATR 72-212|      1072|   5|
# |              Comair|      BOMBARDIER INC|    CL-600-2B19|      2111|   1|
# |              Comair|            CANADAIR|    CL-600-2B19|      1546|   2|
# |              Comair|      BOMBARDIER INC|    CL-600-2C10|      1013|   3|
# |              Comair|      BOMBARDIER INC|     CL600-2D24|       198|   4|
# |              Comair|               PIPER|      PA-28-180|        34|   5|
# |Continental Air L...|              BOEING|        737-524|     12508|   1|
# |Continental Air L...|              BOEING|        737-3TO|     10063|   2|
# |Continental Air L...|              BOEING|        737-824|      9467|   3|
# |Continental Air L...|              BOEING|        757-224|      5154|   4|
# |Continental Air L...|              BOEING|        737-724|      3670|   5|
# |Delta Air Lines Inc.|MCDONNELL DOUGLAS...|          MD-88|     29760|   1|
# |Delta Air Lines Inc.|              BOEING|        757-232|     20554|   2|
# |Delta Air Lines Inc.|              BOEING|        767-332|      6489|   3|
# |Delta Air Lines Inc.|              BOEING|        737-832|      5705|   4|
# |Delta Air Lines Inc.|MCDONNELL DOUGLAS...|          MD-88|      3933|   5|
# |Frontier Airlines...|              AIRBUS|       A319-111|      4141|   1|
# |Frontier Airlines...|              AIRBUS|       A318-111|      1172|   2|
# |Frontier Airlines...|              AIRBUS|       A319-112|       511|   3|
# |Frontier Airlines...|    AIRBUS INDUSTRIE|       A319-111|       388|   4|
# |Frontier Airlines...|    AIRBUS INDUSTRIE|       A319-112|       254|   5|
# |Hawaiian Airlines...|              BOEING|        767-33A|       136|   1|
# |Hawaiian Airlines...|              BOEING|        767-3G5|        47|   2|
# |Hawaiian Airlines...|              BOEING|        767-3CB|        33|   3|
# |Hawaiian Airlines...|              BOEING|        767-332|        31|   4|
# |    Independence Air|      BOMBARDIER INC|    CL-600-2B19|       601|   1|
# |     JetBlue Airways|              AIRBUS|       A320-232|      4763|   1|
# |     JetBlue Airways|    AIRBUS INDUSTRIE|       A320-232|      1628|   2|
# |     JetBlue Airways|             EMBRAER|ERJ 190-100 IGW|      1308|   3|
# |        JetSuite Air|             EMBRAER|      EMB-145LR|     14211|   1|
# |        JetSuite Air|             EMBRAER|      EMB-145XR|      7625|   2|
# |        JetSuite Air|             EMBRAER|      EMB-145EP|      3252|   3|
# |        JetSuite Air|             EMBRAER|      EMB-135LR|      2137|   4|
# |        JetSuite Air|             EMBRAER|      EMB-135ER|       577|   5|
# |  Mesa Airlines Inc.|      BOMBARDIER INC|     CL600-2D24|      1960|   1|
# |  Mesa Airlines Inc.|         DEHAVILLAND|      DHC-8-202|      1654|   2|
# |  Mesa Airlines Inc.|      BOMBARDIER INC|    CL-600-2B19|      1612|   3|
# |  Mesa Airlines Inc.|      BOMBARDIER INC|    CL-600-2C10|      1072|   4|
# |  Mesa Airlines Inc.|            CANADAIR|    CL-600-2B19|       909|   5|
# |Northwest Airline...|   MCDONNELL DOUGLAS|        DC-9-51|      7413|   1|
# |Northwest Airline...|              BOEING|        757-251|      6541|   2|
# |Northwest Airline...|    AIRBUS INDUSTRIE|       A320-212|      4280|   3|
# |Northwest Airline...|             DOUGLAS|        DC-9-31|      4206|   4|
# |Northwest Airline...|    AIRBUS INDUSTRIE|       A320-211|      3756|   5|
# |   PSA Airlines Inc.|      BOMBARDIER INC|    CL-600-2B19|      2111|   1|
# |   PSA Airlines Inc.|            CANADAIR|    CL-600-2B19|      1546|   2|
# |   PSA Airlines Inc.|      BOMBARDIER INC|    CL-600-2C10|      1013|   3|
# |   PSA Airlines Inc.|      BOMBARDIER INC|     CL600-2D24|       198|   4|
# |   PSA Airlines Inc.|               PIPER|      PA-28-180|        34|   5|
# |Skywest Airlines ...|      BOMBARDIER INC|    CL-600-2B19|     13564|   1|
# |Skywest Airlines ...|             EMBRAER|      EMB-120ER|      9523|   2|
# |Skywest Airlines ...|      BOMBARDIER INC|    CL-600-2C10|      5306|   3|
# |Skywest Airlines ...|             EMBRAER|        EMB-120|       914|   4|
# |Skywest Airlines ...|            CANADAIR|    CL-600-2B19|       644|   5|
# |Southwest Airline...|              BOEING|        737-7H4|      5606|   1|
# |Southwest Airline...|              BOEING|        737-3H4|      4755|   2|
# |Southwest Airline...|              BOEING|        737-5H4|       414|   3|
# |Southwest Airline...|              BOEING|        737-3Q8|       316|   4|
# |Southwest Airline...|              BOEING|        737-3A4|       251|   5|
# |          US Airways|    AIRBUS INDUSTRIE|       A319-132|      1983|   1|
# |          US Airways|    AIRBUS INDUSTRIE|       A320-232|      1522|   2|
# |          US Airways|              BOEING|        737-3G7|      1100|   3|
# |          US Airways|    AIRBUS INDUSTRIE|       A320-231|      1014|   4|
# |          US Airways|              BOEING|        737-3B7|       933|   5|
# |     United Airlines|              BOEING|        757-222|     22128|   1|
# |     United Airlines|              BOEING|        737-322|     21076|   2|
# |     United Airlines|    AIRBUS INDUSTRIE|       A320-232|     15134|   3|
# |     United Airlines|              BOEING|        737-522|     11029|   4|
# |     United Airlines|    AIRBUS INDUSTRIE|       A319-131|      7486|   5|
# +--------------------+--------------------+---------------+----------+----+

# %%
airlines_model_ranking.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 91

# %%
def parsePopularModels(airlines_model_ranking):
    results = airlines_model_ranking.collect()
    
    if len(results) == 0:
        return

    results.sort(key=operator.itemgetter(0, 4))
    currAirline = results[0][0]
      
    i = 0
    hasPrintOnce = False
    aircraftTypeString = ""
    while i < len(results):
        if currAirline == results[i][0]:
            aircraftTypeString += "{} {}, ".format(results[i][1], results[i][2])
            i += 1
        else:
            hasPrintOnce = True
            print(
                "{} \t [{}]".format(
                    currAirline, 
                    aircraftTypeString[:-2]
                ), file=sys.stdout
            )
            aircraftTypeString = ""
            currAirline = results[i][0]
    
    if not hasPrintOnce:
         print(
            "{} \t [{}]".format(
                currAirline, 
                aircraftTypeString[:-2]
            ), file=sys.stdout
        )
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
parsePopularModels(airlines_model_ranking)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# AirTran 	 [BOEING 717-200, BOEING 737-76N, BOEING 737-7BD]
# Alaska Airlines Inc. 	 [BOEING 737-4Q8, BOEING 737-790, BOEING 737-490, MCDONNELL DOUGLAS DC-9-83(MD-83), BOEING 737-990]
# American Airlines Inc. 	 [MCDONNELL DOUGLAS DC-9-82(MD-82), MCDONNELL DOUGLAS DC-9-83(MD-83), BOEING 757-223, BOEING 767-223, BOEING 767-323]
# American Eagle Airlines Inc. 	 [EMBRAER EMB-145LR, EMBRAER EMB-135KL, BOMBARDIER INC CL-600-2C10, SAAB-SCANIA SAAB 340B, EMBRAER EMB-135LR]
# Atlantic Southeast Airlines 	 [BOMBARDIER INC CL-600-2B19, BOMBARDIER INC CL-600-2C10, CANADAIR CL-600-2B19, AEROSPATIALE/ALENIA ATR-72-212, AEROSPATIALE ATR 72-212]
# Comair 	 [BOMBARDIER INC CL-600-2B19, CANADAIR CL-600-2B19, BOMBARDIER INC CL-600-2C10, BOMBARDIER INC CL600-2D24, PIPER PA-28-180]
# Continental Air Lines Inc. 	 [BOEING 737-524, BOEING 737-3TO, BOEING 737-824, BOEING 757-224, BOEING 737-724]
# Delta Air Lines Inc. 	 [MCDONNELL DOUGLAS AIRCRAFT CO MD-88, BOEING 757-232, BOEING 767-332, BOEING 737-832, MCDONNELL DOUGLAS CORPORATION MD-88]
# Frontier Airlines Inc. 	 [AIRBUS A319-111, AIRBUS A318-111, AIRBUS A319-112, AIRBUS INDUSTRIE A319-111, AIRBUS INDUSTRIE A319-112]
# Hawaiian Airlines Inc. 	 [BOEING 767-33A, BOEING 767-3G5, BOEING 767-3CB, BOEING 767-332]
# Independence Air 	 [BOMBARDIER INC CL-600-2B19]
# JetBlue Airways 	 [AIRBUS A320-232, AIRBUS INDUSTRIE A320-232, EMBRAER ERJ 190-100 IGW]
# JetSuite Air 	 [EMBRAER EMB-145LR, EMBRAER EMB-145XR, EMBRAER EMB-145EP, EMBRAER EMB-135LR, EMBRAER EMB-135ER]
# Mesa Airlines Inc. 	 [BOMBARDIER INC CL600-2D24, DEHAVILLAND DHC-8-202, BOMBARDIER INC CL-600-2B19, BOMBARDIER INC CL-600-2C10, CANADAIR CL-600-2B19]
# Northwest Airlines Inc. 	 [MCDONNELL DOUGLAS DC-9-51, BOEING 757-251, AIRBUS INDUSTRIE A320-212, DOUGLAS DC-9-31, AIRBUS INDUSTRIE A320-211]
# PSA Airlines Inc. 	 [BOMBARDIER INC CL-600-2B19, CANADAIR CL-600-2B19, BOMBARDIER INC CL-600-2C10, BOMBARDIER INC CL600-2D24, PIPER PA-28-180]
# Skywest Airlines Inc. 	 [BOMBARDIER INC CL-600-2B19, EMBRAER EMB-120ER, BOMBARDIER INC CL-600-2C10, EMBRAER EMB-120, CANADAIR CL-600-2B19]
# Southwest Airlines Co. 	 [BOEING 737-7H4, BOEING 737-3H4, BOEING 737-5H4, BOEING 737-3Q8, BOEING 737-3A4]
# US Airways 	 [AIRBUS INDUSTRIE A319-132, AIRBUS INDUSTRIE A320-232, BOEING 737-3G7, AIRBUS INDUSTRIE A320-231, BOEING 737-3B7]
